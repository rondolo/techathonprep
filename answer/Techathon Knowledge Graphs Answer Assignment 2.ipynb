# %% [markdown]
# <h1>CTRL-F like Search</h1>
# <p>The dataset contains five people with a summary about their career. They have all won prizes or have received awards for their work except for one person. The first assignment is to figure out who hasn't won any prizes or awards. First I'll show you how I tried doing it in the cells below, by using the wonderful "CTRL+f like search".
#
#     The first cell (#1)  uses the <i>pandas.Series.str.contains</i> function with the keyword 'win' and filters the dataset by excluding the people who have the string 'win' in their summary. This approach has narrowed it down to three people.
#
# After adding more keywords in the second cell (#2), there were only two rows (persons) left. Verbs might not be the best key words, so decided using nouns instead: 'prize' and 'award' (#3). This resulted in Rosalind Franklin, who was excluded in the first (#1) search because she had the word 'win' in her summary. I checked the summary and apparantly she didn't have the actual word 'win' in it but it detected the string 'win' in 'owing'.</br>
#     <i>owing to disagreement with her director, john randall, and her colleague maurice wilkins'. </i></br>
#
# This approach is giving me unreliable and wrong results as it only matches strings with strings and shows the importance of tokenizing the text beforehand. The assignment starts after the next three cells, go through them first and check the output of the <i>pandas.Series.str.contains</i> function.
# </p>

# %%
""' !pip install spacy
# !pip install spacy-transformers
# !pip install wikipedia
# !pip install neo4j '''
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      --------------------------------------- 12.8/12.8 MB 34.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (22.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.1)
# Requirement already satisfied: jinja2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.6)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: setuptools in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (65.6.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: colorama in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
from pathlib import Path

#read the assignment's dataset
df = pd.read_excel(Path('assigment1_data.xlsx'))

# %%
#1
keyword = 'win'
df[~df.summary.str.contains('(?i)'+keyword)]
# Out:
#                  person                                            summary
# 0       Jennifer Doudna  Jennifer Anne Doudna  (; born February 19, 196...
# 3        Gertrude Elion  Gertrude "Trudy" Belle Elion (January 23, 1918...
# 4  Rita Levi-Montalcini  Rita Levi-Montalcini (22 April 1909 – 30 Decem...

# %%
#2
keyword = 'win|receive'
df[~df.summary.str.contains('(?i)'+keyword)]
# Out:
#                  person                                            summary
# 3        Gertrude Elion  Gertrude "Trudy" Belle Elion (January 23, 1918...
# 4  Rita Levi-Montalcini  Rita Levi-Montalcini (22 April 1909 – 30 Decem...

# %%
#3
keyword = 'prize|award'
df[~df.summary.str.contains('(?i)'+keyword)]
# Out:
#               person                                            summary
# 2  Rosalind Franklin  Rosalind Elsie Franklin (25 July 1920 – 16 Apr...

# %% [markdown]
# <b>Assignment 1:</b> </br>
# As mentioned before, the first assignment is to find out which person hasn't won an award. The Python NLP package spaCY is used to  improve the 'CTRL-F like search.
#
# First we use tokenization and lemmatization in order to match the key words (relating to awards) with words in the texts of the 5 persons. For information about tokenization, lemmatization, as well as Named Entity Recogntion, please refer to the previous Techathon NLP II:
# https://github.com/DataScienceOrdina/techathon-NLP-II/blob/main/spacy-hackathon-presentation-november-2022.pdf
# https://github.com/DataScienceOrdina/techathon-NLP-II/blob/main/Assignments/Assignment-1-spaCy-101.ipynb

# %%
import pandas as pd
from pathlib import Path
import spacy
# !python -m spacy download en_core_web_sm
import re

#read the assignment's dataset
df = pd.read_excel(Path('assigment1_data.xlsx'))

#Language class with the English model 'en_core_web_sm' is loaded
nlp = spacy.load('en_core_web_sm')

#Bonus question: "cleaning" data important or not?
def alphanumericalOnly(text):
    return re.sub(r'[^a-zA-Z0-9 ]', '', text).lower()
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.6)
# Requirement already satisfied: pathy>=0.3.5 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.4)
# Requirement already satisfied: numpy>=1.15.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.1)
# Requirement already satisfied: setuptools in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (65.6.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: jinja2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (22.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: colorama in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# You can try to play around with different kinds of _keywords_ to improve the search.

# %%
keywords = ["win", "award", "prize", "receive"]
keywords_nlp = [nlp(k) for k in keywords]
docs = [nlp(doc) for doc in df['summary']] 
spacy.displacy.render(docs, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Anne Doudna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#   (; born
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 19, 1964
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  biochemist who has done pioneering work in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CRISPR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  gene editing, and made other fundamental contributions in biochemistry and genetics. Doudna was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  women to share a
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nobel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  in the sciences. She received the 2020
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nobel Prize in Chemistry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emmanuelle Charpentier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , &quot;for the development of a method for genome editing.&quot; She is
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Li Ka Shing Chancellor's Chair Professor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Chemistry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Molecular and Cell Biology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of California, Berkeley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . She has been an investigator with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Howard Hughes Medical Institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1997
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>She graduated from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pomona College
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1985
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and earned a
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ph.D.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harvard Medical School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1989
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Apart from her professorship at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Berkeley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , she is also president and chair of the board of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Innovative Genomics Institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a faculty scientist at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lawrence Berkeley National Laboratory
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a senior investigator at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius

# %%
awardCounter = {"Jennifer":0, "Rachel":0, "Rosalind":0,
                "Gertrude":0, "Rita":0}
for doc in docs:
    for token in doc:
        for k in keywords_nlp:
            if (token.lemma_.casefold() == k[0].lemma_):
                awardCounter[doc[0].text] += 1
                print(f"Person: {doc[0].text}, token: {token}, "
                      #f"token_lemma: {token.lemma_.casefold()}, " 
                      f"keyword: {k[0].lemma_}")

print(f"\n{awardCounter}")
# Out:
# Person: Jennifer, token: received, keyword: receive
# Person: Jennifer, token: Prize, keyword: prize
# Person: Jennifer, token: awards, keyword: award
# Person: Jennifer, token: Award, keyword: award
# Person: Jennifer, token: Prize, keyword: prize
# Person: Jennifer, token: Prize, keyword: prize
# Person: Jennifer, token: Prize, keyword: prize
# Person: Jennifer, token: Award, keyword: award
# Person: Jennifer, token: Prize, keyword: prize
# Person: Rachel, token: won, keyword: win
# Person: Rachel, token: Award, keyword: award
# Person: Rachel, token: awarded, keyword: award
# Person: Gertrude, token: Prize, keyword: prize
# Person: Rita, token: awarded, keyword: award
# Person: Rita, token: Prize, keyword: prize
#
# {'Jennifer': 9, 'Rachel': 3, 'Rosalind': 0, 'Gertrude': 1, 'Rita': 2}

# %% [markdown]
# Now we will use word embeddings to find matches with our search words. Word embeddings were introduced in a previous Techathon, but for quick refresh you can look it up here:
#
# https://en.wikipedia.org/wiki/Word_embedding
# https://www.shanelynn.ie/get-busy-with-word-embeddings-introduction/

# %%
#Download medium sized language model, which includes word embeddings
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.4.1/en_core_web_md-3.4.1-py3-none-any.whl (42.8 MB)
#      --------------------------------------- 42.8/42.8 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from en-core-web-md==3.4.1) (3.4.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.4.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: jinja2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (5.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (22.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.28.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.24.1)
# Requirement already satisfied: setuptools in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (65.6.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.10.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.0.3)
# Requirement already satisfied: colorama in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\x\python\anaconda3\envs\semantic_search_techathon\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# Try playing around with different settings for _similarityThreshold_, as well as with different _keywords_.

# %%
nlp = spacy.load('en_core_web_md')
keywords = ["win", "award", "prize", "receive"]
keywords_nlp = [nlp(k) for k in keywords]
docs = [nlp(doc) for doc in df['summary']] 

awardCounter = {"Jennifer":0, "Rachel":0, "Rosalind":0,
                "Gertrude":0, "Rita":0}

similarityThreshold = 0.5
for doc in docs:
    for token in doc:
        for k in keywords_nlp:
            similarityScore = token.similarity(k)
            if similarityScore > similarityThreshold:
                awardCounter[doc[0].text] += 1
                print(f'Person: {doc[0].text}, {token} <-> {k}, '
                    f'similarity: {similarityScore}')

print(f"\n{awardCounter}")

#UserWarning: [W008] Evaluating Token.similarity based on empty vectors. 
# -> when evaluating unknown tokens that have no valid word vector
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_14764\3700666728.py:13: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   similarityScore = token.similarity(k)
# Person: Jennifer, received <-> receive, similarity: 0.7367027486482727
# Person: Jennifer, Prize <-> award, similarity: 0.6396464987419995
# Person: Jennifer, Prize <-> prize, similarity: 0.6891455645215978
# Person: Jennifer, prestigious <-> award, similarity: 0.5954339461101952
# Person: Jennifer, awards <-> award, similarity: 0.8765914436826451
# Person: Jennifer, awards <-> prize, similarity: 0.6013163726404726
# Person: Jennifer, Award <-> award, similarity: 0.7827086338667512
# Person: Jennifer, Prize <-> award, similarity: 0.6396464987419995
# Person: Jennifer, Prize <-> prize, similarity: 0.6891455645215978
# Person: Jennifer, recipient <-> award, similarity: 0.5305744256883699
# Person: Jennifer, recipient <-> receive, similarity: 0.559757817169588
# Person: Jennifer, Prize <-> award, similarity: 0.6396464987419995
# Person: Jennifer, Prize <-> prize, similarity: 0.6891455645215978
# Person: Jennifer, Prize <-> award, similarity: 0.6396464987419995
# Person: Jennifer, Prize <-> prize, similarity: 0.6891455645215978
# Person: Jennifer, Award <-> award, similarity: 0.7827086338667512
# Person: Jennifer, Prize <-> award, similarity: 0.6396464987419995
# Person: Jennifer, Prize <-> prize, similarity: 0.6891455645215978
# Person: Rachel, won <-> win, similarity: 0.6438067285499628
# Person: Rachel, Award <-> award, similarity: 0.7827086338667512
# Person: Rachel, recognition <-> award, similarity: 0.5311790631269874
# Person: Rachel, awarded <-> award, similarity: 0.6537520477291149
# Person: Rachel, Medal <-> award, similarity: 0.5329690359734576
# Person: Rosalind, earn <-> receive, similarity: 0.5972132899564773
# Person: Gertrude, Prize <-> award, similarity: 0.6396464987419995
# Person: Gertrude, Prize <-> prize, similarity: 0.6891455645215978
# Person: Rita, honored <-> award, similarity: 0.5510605436634738
# Person: Rita, awarded <-> award, similarity: 0.6537520477291149
# Person: Rita, Prize <-> award, similarity: 0.6396464987419995
# Person: Rita, Prize <-> prize, similarity: 0.6891455645215978
# Person: Rita, honor <-> award, similarity: 0.5008782820865654
# Person: Rita, given <-> receive, similarity: 0.6192773811958882
#
# {'Jennifer': 18, 'Rachel': 5, 'Rosalind': 1, 'Gertrude': 2, 'Rita': 6}

# %% [markdown]
# <b>Assignment 2:</b>
# Now do it yourself: find out which one of the five persons worked at a Public Ivy School. Public Ivy School is an informal term for prestigious universities in the United States of America.
# (See: https://en.wikipedia.org/wiki/Public_Ivy)
#
# Hint: The words _Public Ivy School_ themself are not in the data.

# %%
nlp = spacy.load('en_core_web_md')
keyword_nlp = nlp("Public Ivy School")
docs = [nlp(doc) for doc in df['summary']] 

awardCounter = {"Jennifer":0, "Rachel":0, "Rosalind":0,
                "Gertrude":0, "Rita":0}

similarityThreshold = 0.5
for doc in docs:
    for token in doc:
        similarityScore = token.similarity(keyword_nlp)
        if similarityScore > similarityThreshold:
            awardCounter[doc[0].text] += 1
            print(f'Person: {doc[0].text}, {token} <-> {keyword_nlp}, '
                  f'similarity: {similarityScore}')

print(f"\n{awardCounter}")
# Out:
# Person: Jennifer, University <-> Public Ivy School, similarity: 0.6291199222892067
# Person: Jennifer, Institute <-> Public Ivy School, similarity: 0.5324329089480745
# Person: Jennifer, graduated <-> Public Ivy School, similarity: 0.5178858279667898
# Person: Jennifer, College <-> Public Ivy School, similarity: 0.6558392707641082
# Person: Jennifer, Harvard <-> Public Ivy School, similarity: 0.5049717602257867
# Person: Jennifer, School <-> Public Ivy School, similarity: 0.8072080710135979
# Person: Jennifer, Institute <-> Public Ivy School, similarity: 0.5324329089480745
# Person: Jennifer, Institutes <-> Public Ivy School, similarity: 0.5055165265838937
# Person: Jennifer, University <-> Public Ivy School, similarity: 0.6291199222892067
# Person: Rosalind, graduated <-> Public Ivy School, similarity: 0.5178858279667898
# Person: Rosalind, College <-> Public Ivy School, similarity: 0.6558392707641082
# Person: Rosalind, University <-> Public Ivy School, similarity: 0.6291199222892067
# Person: Rosalind, College <-> Public Ivy School, similarity: 0.6558392707641082
# Person: Rosalind, College <-> Public Ivy School, similarity: 0.6558392707641082
#
# {'Jennifer': 9, 'Rachel': 0, 'Rosalind': 5, 'Gertrude': 0, 'Rita': 0}
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_14764\1634256177.py:11: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   similarityScore = token.similarity(keyword_nlp)

# %%
#Hint: comparing tokens versus comparing entities. Which would work better?
spacy.displacy.render(docs, style='ent')

# %%
#Answer: now comparing entities instead of tokens.
nlp = spacy.load('en_core_web_md') 
keyword_nlp = nlp("Public Ivy School")
docs = [nlp(doc) for doc in df['summary']]

awardCounter = {"Jennifer":0, "Rachel":0, "Rosalind":0,
                "Gertrude":0, "Rita":0}

similarityThreshold = 0.5
for doc in docs:
    for ent in doc.ents:
        similarityScore = ent.similarity(keyword_nlp)
        if similarityScore > similarityThreshold:
            awardCounter[doc[0].text] += 1
            print(f'Person: {doc[0].text}, {ent} <-> {keyword_nlp}, '
                  f'similarity: {similarityScore}')

print(f"\n{awardCounter}")
# Out:
# Person: Jennifer, the Howard Hughes Medical Institute <-> Public Ivy School, similarity: 0.507655762343079
# Person: Jennifer, Pomona College <-> Public Ivy School, similarity: 0.681009594596115
# Person: Jennifer, Harvard Medical School <-> Public Ivy School, similarity: 0.7992868418085236
# Person: Jennifer, Lawrence Berkeley National Laboratory <-> Public Ivy School, similarity: 0.5833282496347029
# Person: Rosalind, Newnham College <-> Public Ivy School, similarity: 0.6706007641001862
# Person: Rosalind, Birkbeck College <-> Public Ivy School, similarity: 0.6191564816684598
#
# {'Jennifer': 4, 'Rachel': 0, 'Rosalind': 2, 'Gertrude': 0, 'Rita': 0}
